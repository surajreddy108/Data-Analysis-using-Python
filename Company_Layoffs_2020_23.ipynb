# %% [markdown]
# dataset: https://www.kaggle.com/datasets/swaptr/layoffs-2022

# %%
import pandas as pd
df=pd.read_csv('/content/layoffs.csv')

# %%
df
# Out:
#              company        location        industry  total_laid_off  \
# 0                Ola       Bengaluru  Transportation           200.0
# 1       Lending Club     SF Bay Area         Finance           225.0
# 2          SmartNews           Tokyo           Media           120.0
# 3               Pier       Sao Paulo         Finance           111.0
# 4     Blockchain.com          London          Crypto           110.0
# ...              ...             ...             ...             ...
# 1941    HopSkipDrive     Los Angeles  Transportation             8.0
# 1942     Panda Squad     SF Bay Area        Consumer             6.0
# 1943   Tamara Mellon     Los Angeles          Retail            20.0
# 1944        EasyPost  Salt Lake City       Logistics            75.0
# 1945       Homebound     SF Bay Area     Real Estate             NaN
#
#       percentage_laid_off        date     stage         country  funds_raised
# ...

# %%
df.count()
# Out:
# company                1946
# location               1946
# industry               1946
# total_laid_off         1350
# percentage_laid_off    1315
# date                   1945
# stage                  1942
# country                1946
# funds_raised           1796
# dtype: int64

# %%
df.isnull().sum()
# Out:
# company                  0
# location                 0
# industry                 0
# total_laid_off         596
# percentage_laid_off    631
# date                     1
# stage                    4
# country                  0
# funds_raised           150
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())   # white space are representing null values

# %% [markdown]
# **Country wise layoffs done**

# %%
df.head(2)
# Out:
#         company     location        industry  total_laid_off  \
# 0           Ola    Bengaluru  Transportation           200.0
# 1  Lending Club  SF Bay Area         Finance           225.0
#
#    percentage_laid_off        date     stage        country  funds_raised
# 0                  NaN  2023-01-13  Series J          India        5000.0
# 1                 0.14  2023-01-12       IPO  United States         392.0

# %%
df.groupby('country').sum()
# Out:
#                       total_laid_off  percentage_laid_off  funds_raised
# country
# Argentina                      323.0               0.9100  5.720000e+02
# Australia                     1434.0              11.5900  3.562000e+03
# Austria                        570.0               0.2700  1.918000e+03
# Bahrain                          0.0               0.0000  2.020000e+02
# Belgium                          0.0               0.0000  5.960000e+02
# Brazil                        8221.0               9.5200  1.570770e+04
# Bulgaria                       120.0               0.1000  0.000000e+00
# Canada                        5393.0              14.8500  9.873300e+03
# Chile                           30.0               0.0000  2.060000e+02
# China                         4705.0               1.2900  7.130200e+04
# Colombia                        30.0               0.0300  5.840000e+02
# Czech Republic                   0.0               0.0000  4.100000e+01
# ...

# %%
df.groupby('country')['total_laid_off'].sum().sort_values(ascending=False)
# Out:
# country
# United States           186789.0
# India                    31841.0
# Brazil                    8221.0
# Singapore                 5906.0
# Canada                    5393.0
# Netherlands               5220.0
# United Kingdom            5080.0
# China                     4705.0
# Germany                   4445.0
# Indonesia                 3161.0
# Israel                    3038.0
# Sweden                    2014.0
# Australia                 1434.0
# United Arab Emirates       995.0
# Hong Kong                  730.0
# Austria                    570.0
# Nigeria                    491.0
# Russia                     400.0
# Kenya                      349.0
# Argentina                  323.0
# Senegal                    300.0
# Mexico                     270.0
# Estonia                    267.0
# Finland                    250.0
# Denmark                    240.0
# Ireland                    230.0
# Myanmar                    200.0
# Norway                     140.0
# ...

# %%
# Out:
#             total_laid_off  percentage_laid_off  funds_raised
# date
# 2020-03-16           130.0                 1.22          84.1
# 2020-03-19           120.0                 1.00         301.0
# 2020-03-20           784.0                 1.98         651.0
# 2020-03-23           525.0                 0.73        2117.0
# 2020-03-24           530.0                 0.98         523.0
# ...                    ...                  ...           ...
# 2023-01-09           315.0                 0.77        1802.0
# 2023-01-10          2060.0                 1.28        3320.0
# 2023-01-11          1383.0                 0.90        8814.0
# 2023-01-12           770.0                 1.79        2451.0
# 2023-01-13           200.0                 0.00        5000.0
#
# [377 rows x 3 columns]

# %% [markdown]
# **Remove all Countries where total_laid_off employees are less than 100.**

# %%
df[df.total_laid_off<100]
# Out:
#                     company        location        industry  total_laid_off  \
# 7     Definitive Healthcare          Boston      Healthcare            55.0
# 8              Career Karma     SF Bay Area       Education            22.0
# 18                  CoinDCX          Mumbai          Crypto            80.0
# 19                HashiCorp     SF Bay Area        Security            69.0
# 20                Intrinsic     SF Bay Area           Other            40.0
# ...                     ...             ...             ...             ...
# 1939               Help.com          Austin         Support            16.0
# 1941           HopSkipDrive     Los Angeles  Transportation             8.0
# 1942            Panda Squad     SF Bay Area        Consumer             6.0
# 1943          Tamara Mellon     Los Angeles          Retail            20.0
# 1944               EasyPost  Salt Lake City       Logistics            75.0
#
# ...

# %%
df=df[~(df.total_laid_off<100)] # to remove the rows for a particular condition

# %% [markdown]
# **In which country maximum layoff done**

# %%
df.groupby('country').total_laid_off.sum().sort_values(ascending=False).head(1)
# Out:
# country
# United States    163407.0
# Name: total_laid_off, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1135 entries, 0 to 1945
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              1135 non-null   object
#  1   location             1135 non-null   object
#  2   industry             1135 non-null   object
#  3   total_laid_off       539 non-null    float64
#  4   percentage_laid_off  719 non-null    float64
#  5   date                 1134 non-null   object
#  6   stage                1132 non-null   object
#  7   country              1135 non-null   object
#  8   funds_raised         1040 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 121.0+ KB

# %% [markdown]
# **year wise layoff analysis**

# %%
df.groupby(pd.DatetimeIndex(df['date']).year)['total_laid_off'].sum()
# Out:
# date
# 2020.0     68855.0
# 2021.0     14329.0
# 2022.0    132800.0
# 2023.0     22395.0
# Name: total_laid_off, dtype: float64

# %% [markdown]
# **Top 10 companies with maximum layoffs**

# %%
df.head(2)
# Out:
#         company     location        industry  total_laid_off  \
# 0           Ola    Bengaluru  Transportation           200.0
# 1  Lending Club  SF Bay Area         Finance           225.0
#
#    percentage_laid_off        date     stage        country  funds_raised
# 0                  NaN  2023-01-13  Series J          India        5000.0
# 1                 0.14  2023-01-12       IPO  United States         392.0

# %%
df.groupby('company')['total_laid_off'].sum().sort_values(ascending =False).head(10)
# Out:
# company
# Amazon         18150.0
# Meta           11000.0
# Salesforce     10000.0
# Uber            7525.0
# Booking.com     4601.0
# Cisco           4100.0
# Peloton         4084.0
# Carvana         4000.0
# Better.com      3900.0
# Bytedance       3750.0
# Name: total_laid_off, dtype: float64
